# %%
#Open source computer Vision

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img =cv2.imread('00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(img)

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (1300, 1950, 3)

# %%
fix_img.shape
# Out:
# (1300, 1950, 3)

# %%
cv2.imwrite('duplicate.jpg',fix_img)
# Out:
# True

# %%
new_img = cv2.flip(fix_img,0)

# %%
plt.imshow(new_img)

# %%
resize_img=cv2.resize(new_img,(1000,700))

# %%
resize_img.shape
# Out:
# (700, 1000, 3)

# %%
plt.imshow(resize_img)
